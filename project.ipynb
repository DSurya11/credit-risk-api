# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("loan_approval_dataset.csv")

# %%
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df = df.drop(columns = ["loan_id"])

# %%
df.columns = df.columns.str.strip()
for c in df.columns:
    print(repr(c))
# Out:
# 'no_of_dependents'
# 'education'
# 'self_employed'
# 'income_annum'
# 'loan_amount'
# 'loan_term'
# 'cibil_score'
# 'residential_assets_value'
# 'commercial_assets_value'
# 'luxury_assets_value'
# 'bank_asset_value'
# 'loan_status'

# %%
x = df[
    [
        "no_of_dependents",
        # "education",
        # "self_employed",
        "income_annum",
        "loan_amount",
        "loan_term",
        "cibil_score",
        "bank_asset_value"
    ]
]

y = (
    df["loan_status"]
    .str.strip()
    .map({"Approved": 1, "Rejected": 0})
)

# %%
x
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       9600000     29900000         12          778
# 1                    0       4100000     12200000          8          417
# 2                    3       9100000     29700000         20          506
# 3                    3       8200000     30700000          8          467
# 4                    5       9800000     24200000         20          382
# ...                ...           ...          ...        ...          ...
# 4264                 5       1000000      2300000         12          317
# 4265                 0       3300000     11300000         20          559
# 4266                 2       6500000     23900000         18          457
# 4267                 1       4100000     12800000          8          780
# 4268                 1       9200000     29700000         10          607
#
#       bank_asset_value
# 0              8000000
# 1              3300000
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4264    0
# 4265    1
# 4266    0
# 4267    1
# 4268    1
# Name: loan_status, Length: 4269, dtype: int64

# %%
x.isna().sum()
# Out:
# no_of_dependents    0
# income_annum        0
# loan_amount         0
# loan_term           0
# cibil_score         0
# bank_asset_value    0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   no_of_dependents  4269 non-null   int64
#  1   income_annum      4269 non-null   int64
#  2   loan_amount       4269 non-null   int64
#  3   loan_term         4269 non-null   int64
#  4   cibil_score       4269 non-null   int64
#  5   bank_asset_value  4269 non-null   int64
# dtypes: int64(6)
# memory usage: 200.2 KB

# %%
num_cols = [
    "no_of_dependents",
    "income_annum",
    "loan_amount",
    "loan_term",
    "cibil_score",
    "bank_asset_value"
]

# %%
sc = StandardScaler()
x_train[num_cols]  = sc.fit_transform(x_train[num_cols])

# %%
x_test[num_cols] = sc.transform(x_test[num_cols])

# %%
x_train[num_cols].mean()
x_train[num_cols].std()
# Out:
# no_of_dependents    1.000146
# income_annum        1.000146
# loan_amount         1.000146
# loan_term           1.000146
# cibil_score         1.000146
# bank_asset_value    1.000146
# dtype: float64

# %%
x_train
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 1675          1.512508      1.009500     1.624772  -0.860003    -0.187401
# 1164         -1.435001      1.614171     2.077128   0.188894     0.637397
# 192          -0.845499     -1.515891    -1.354157  -0.510371     0.474761
# 910          -0.255997     -0.057566    -0.228784   1.237791     0.892968
# 567           1.512508     -0.733375    -0.449445   0.188894    -0.925072
# ...                ...           ...          ...        ...          ...
# 3444         -1.435001     -1.338046    -1.155562   0.888158    -0.408121
# 466           1.512508     -1.622597    -1.475521   1.237791    -1.099324
# 3092          0.923006      1.258482     0.598697   0.888158    -0.878604
# 3772         -0.255997      0.689380     0.686961   0.188894    -0.344228
# 860           0.923006      0.404829     0.234605  -0.860003     1.375068
#
#       bank_asset_value
# 1675          1.160414
# 1164          0.882020
# ...

# %%
import joblib

# %%
joblib.dump(sc, "standard_scaler.pkl")
# Out:
# ['standard_scaler.pkl']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
param_dist = {
    "C": np.logspace(-3, 2, 20),
    "class_weight": [None, "balanced"]
}

# %%
# x_train["education"] = x_train["education"].str.strip()
# x_train["self_employed"] = x_train["self_employed"].str.strip()

# x_test["education"] = x_test["education"].str.strip()
# x_test["self_employed"] = x_test["self_employed"].str.strip()

# %%
# x_train["education"] = x_train["education"].map({
#     "Graduate": 1,
#     "Not Graduate": 0
# })

# x_test["education"] = x_test["education"].map({
#     "Graduate": 1,
#     "Not Graduate": 0
# })

# x_train["self_employed"] = x_train["self_employed"].map({
#     "Yes": 1,
#     "No": 0
# })

# x_test["self_employed"] = x_test["self_employed"].map({
#     "Yes": 1,
#     "No": 0
# })

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

rf = RandomForestClassifier(random_state=42)

param_dist = {
    "n_estimators": [100, 200, 300, 500],
    "max_depth": [None, 5, 10, 15, 20],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["sqrt", "log2"],
    "bootstrap": [True, False]
}

rand = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=20,
    scoring="roc_auc",
    cv=5,
    random_state=42,
    n_jobs=-1
)

rand.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [None, 5, 10, 15, 20],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300, 500]},
#                    random_state=42, scoring='roc_auc')

# %%
best_model = rand.best_estimator_
print(rand.best_params_)
print(rand.best_score_)
# Out:
# {'n_estimators': 300, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'bootstrap': True}
# 0.9960324542871714

# %%
y_pred = best_model.predict(x_test)

# %%
risk_probability = best_model.predict_proba(x_test)[:, 1]

for t in [0.55, 0.6, 0.65, 0.7]:
    y_custom = (risk_probability >= t).astype(int)
    print("\nthreshold:", t)
    print(classification_report(y_test, y_custom))
# Out:
# threshold: 0.55
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       318
#            1       0.99      0.99      0.99       536
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854
#
#
# threshold: 0.6
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       318
#            1       0.99      0.98      0.98       536
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854
#
#
# threshold: 0.65
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       318
#            1       1.00      0.97      0.98       536
#
#     accuracy                           0.98       854
# ...

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9812646370023419

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       318
#            1       0.98      0.99      0.99       536
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854

# %%
threshold = 0.55



final_decision = [
    "Approved" if p >= threshold else "Rejected"
    for p in risk_probability
]

# %%
y_final = [1 if d == "Approved" else 0 for d in final_decision]

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("accuracy:", accuracy_score(y_test, y_final))
print(classification_report(y_test, y_final))
print(confusion_matrix(y_test, y_final))
# Out:
# accuracy: 0.9824355971896955
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       318
#            1       0.99      0.99      0.99       536
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854
#
# [[311   7]
#  [  8 528]]

# %%
bundle = {
    "model": best_model,
    "scaler": sc,
    "features": list(x_train.columns),
    "threshold": 0.55
}

joblib.dump(bundle, "credit_risk_artifacts.pkl")
# Out:
# ['credit_risk_artifacts.pkl']

# %%
x_train.columns
# Out:
# Index(['no_of_dependents', 'income_annum', 'loan_amount', 'loan_term',
#        'cibil_score', 'bank_asset_value'],
#       dtype='object')
